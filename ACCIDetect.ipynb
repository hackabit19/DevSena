# %%
from keras.models import load_model
from collections import deque
import numpy as np
import argparse
import time
import pickle
import cv2
from twilio.rest import Client
camid = 101   
location = 'Hackabit BIT MESHRA,Ranchi, Jharkhand ,India' 

ap = argparse.ArgumentParser()
ap.add_argument("-m", "--model", required=True,
	help="path to trained serialized model")
ap.add_argument("-l", "--label-bin", required=True,
	help="path to  label binarizer")
ap.add_argument("-i", "--input", required=False,
	help="path to our input video")
ap.add_argument("-o", "--output", required=True,
	help="path to our output video")
ap.add_argument("-s", "--size", type=int, default=128,
	help="size of queue for averaging")
args = vars(ap.parse_args('-m model -l label-bin -o output'.split()))

print("[INFO] loading model and label binarizer...")
model = load_model(args["model"])
lb = pickle.loads(open(args["label_bin"], "rb").read())

mean = np.array([123.68, 116.779, 103.939][::1], dtype="float32")
Q = deque(maxlen=args["size"])

print("[INFO] starting video stream...")
vs = cv2.VideoCapture('demo.mp4')
writer = None
time.sleep(2.0)
#-------------------
(W, H) = (None, None)
client = Client("AC358d6a22cb7b8966c3267905a9XXXXXXX", "2f9227d6e04fd21e44d85772c5XXXXX") 
prelabel = ''
prelabel = ''
ok = 'Normal'
fi_label = []
framecount = 0
while True:
	flag,frame = vs.read()


	if W is None or H is None:
		(H, W) = frame.shape[:2]


	output = frame.copy()
	frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
	frame = cv2.resize(frame, (224, 224)).astype("float32")
	frame -= mean


	preds = model.predict(np.expand_dims(frame, axis=0))[0]

	prediction = preds.argmax(axis=0)
	Q.append(preds)


	results = np.array(Q).mean(axis=0)
	print('Results = ', results)
	maxprob = np.max(results)
	print('Maximun Probability = ', maxprob)
	i = np.argmax(results)
	label = lb[i]

	rest = 1 - maxprob
    
	diff = (maxprob) - (rest)
	print('Difference of prob ', diff)
	th = 100
	if diff > .80:
		th = diff
      
        
        
        
	if (preds[prediction]) < th:
		text = "Alert : {} - {:.2f}%".format((ok), 100 - (maxprob * 100))
		cv2.putText(output, text, (35, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.25, (0, 255, 0), 5)
	else:
		fi_label = np.append(fi_label, label)
		text = "Alert : {} - {:.2f}%".format((label), maxprob * 100)
		cv2.putText(output, text, (35, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.25, (0, 255, 0), 5) 
		if label != prelabel: 
			client.messages.create(to="+917975720047", 
                       from_="+12054967936", 
                       body='\n'+ str(text) +'\n Satellite: ' + str(camid) + '\n Orbit: ' + location)
		prelabel = label


	if writer is None:
		fourcc = cv2.VideoWriter_fourcc(*"MJPG")
		writer = cv2.VideoWriter(args["output"], fourcc, 30,
			(W, H), True)

	writer.write(output)

	# show the output image
	cv2.imshow("Output", output)
	key = cv2.waitKey(1) & 0xFF

	if key == ord("q"):
		break

# release the file pointers
print("[INFO] cleaning up...")
writer.release()
vs.stream.release()
# Out:
# Using TensorFlow backend.
# [INFO] loading model and label binarizer...
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Abhinav\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# [INFO] starting video stream...
# Results =  [4.3293534e-04 3.8548801e-03 2.4781943e-05 9.9568731e-01]
# Maximun Probability =  0.9956873
# Difference of prob  0.9913746118545532
# Results =  [4.1209286e-04 3.3790225e-03 2.1892400e-05 9.9618697e-01]
# Maximun Probability =  0.996187
# Difference of prob  0.9923739433288574
# Results =  [3.8231528e-04 3.0400951e-03 1.9718520e-05 9.9655789e-01]
# Maximun Probability =  0.9965579
# Difference of prob  0.9931157827377319
# Results =  [4.0823285e-04 3.4692693e-03 1.9826053e-05 9.9610269e-01]
# Maximun Probability =  0.9961027
# Difference of prob  0.9922053813934326
# Results =  [4.4166693e-04 3.6382810e-03 2.0791607e-05 9.9589932e-01]
# Maximun Probability =  0.9958993
# Difference of prob  0.9917986392974854
# Results =  [4.6395161e-04 3.8080963e-03 2.1883048e-05 9.9570608e-01]
# Maximun Probability =  0.9957061
# Difference of prob  0.9914121627807617
# Results =  [4.8713089e-04 3.8926492e-03 2.2053255e-05 9.9559820e-01]
# Maximun Probability =  0.9955982
# Difference of prob  0.9911963939666748
# Results =  [5.0497561e-04 4.2713946e-03 2.2234248e-05 9.9520141e-01]
# Maximun Probability =  0.9952014
# Difference of prob  0.9904028177261353
# Results =  [5.3840579e-04 4.8335474e-03 2.2795035e-05 9.9460530e-01]
# Maximun Probability =  0.9946053
# Difference of prob  0.9892106056213379
# Results =  [5.6717161e-04 5.0472245e-03 2.2638722e-05 9.9436301e-01]
# Maximun Probability =  0.994363
# Difference of prob  0.988726019859314
# Results =  [5.6933356e-04 5.3468863e-03 2.2271177e-05 9.9406153e-01]
# Maximun Probability =  0.9940615
# Difference of prob  0.9881230592727661
# Results =  [5.8164430e-04 6.0448260e-03 2.2676977e-05 9.9335092e-01]
# Maximun Probability =  0.9933509
# Difference of prob  0.9867018461227417
# Results =  [6.0467137e-04 6.9230017e-03 2.3635774e-05 9.9244875e-01]
# Maximun Probability =  0.99244875
# Difference of prob  0.9848974943161011
# Results =  [6.2682637e-04 7.9353545e-03 2.4414652e-05 9.9141347e-01]
# Maximun Probability =  0.9914135
# Difference of prob  0.9828269481658936
# Results =  [6.3753448e-04 8.5867830e-03 2.4880212e-05 9.9075091e-01]
# Maximun Probability =  0.9907509
# Difference of prob  0.9815018177032471
# Results =  [6.5410085e-04 9.1052987e-03 2.5656278e-05 9.9021500e-01]
# Maximun Probability =  0.990215
# Difference of prob  0.980430006980896
# Results =  [6.9796632e-04 1.0092898e-02 2.7582983e-05 9.8918164e-01]
# Maximun Probability =  0.98918164
# Difference of prob  0.9783632755279541
# Results =  [7.2438776e-04 1.0947216e-02 2.9122813e-05 9.8829937e-01]
# Maximun Probability =  0.98829937
# Difference of prob  0.9765987396240234
# Results =  [7.5147673e-04 1.1573686e-02 2.9684281e-05 9.8764521e-01]
# Maximun Probability =  0.9876452
# Difference of prob  0.9752904176712036
# Results =  [7.7163614e-04 1.1902476e-02 3.0644944e-05 9.8729527e-01]
# Maximun Probability =  0.98729527
# Difference of prob  0.974590539932251
# Results =  [7.8111282e-04 1.1962936e-02 3.1487194e-05 9.8722446e-01]
# Maximun Probability =  0.98722446
# Difference of prob  0.9744489192962646
# Results =  [7.9536973e-04 1.2239532e-02 3.2128635e-05 9.8693299e-01]
# Maximun Probability =  0.986933
# Difference of prob  0.9738659858703613
# Results =  [8.0912141e-04 1.2306459e-02 3.3128850e-05 9.8685133e-01]
# Maximun Probability =  0.98685133
# Difference of prob  0.9737026691436768
# Results =  [8.0843450e-04 1.2258045e-02 3.3805798e-05 9.8689979e-01]
# Maximun Probability =  0.9868998
# Difference of prob  0.9737995862960815
# Results =  [8.0780208e-04 1.2157122e-02 3.4596644e-05 9.8700052e-01]
# Maximun Probability =  0.9870005
# Difference of prob  0.9740010499954224
# Results =  [8.06554453e-04 1.20251905e-02 3.50122245e-05 9.87133265e-01]
# Maximun Probability =  0.98713326
# Difference of prob  0.974266529083252
# Results =  [8.0523879e-04 1.1929464e-02 3.5087825e-05 9.8723024e-01]
# Maximun Probability =  0.98723024
# Difference of prob  0.9744604825973511
# Results =  [8.1264385e-04 1.1937265e-02 3.5024968e-05 9.8721510e-01]
# Maximun Probability =  0.9872151
# Difference of prob  0.9744302034378052
# Results =  [8.1590679e-04 1.1802849e-02 3.4994286e-05 9.8734629e-01]
# Maximun Probability =  0.9873463
# Difference of prob  0.9746925830841064
# Results =  [8.1981259e-04 1.1644389e-02 3.4952551e-05 9.8750091e-01]
# Maximun Probability =  0.9875009
# Difference of prob  0.9750018119812012
# Results =  [8.1984664e-04 1.1417150e-02 3.5289904e-05 9.8772776e-01]
# Maximun Probability =  0.98772776
# Difference of prob  0.9754555225372314
# Results =  [8.2474144e-04 1.1230412e-02 3.5831254e-05 9.8790908e-01]
# Maximun Probability =  0.9879091
# Difference of prob  0.9758181571960449
# Results =  [8.3967979e-04 1.1137408e-02 3.6763897e-05 9.8798627e-01]
# Maximun Probability =  0.98798627
# Difference of prob  0.9759725332260132
# Results =  [8.5065997e-04 1.0984491e-02 3.7431648e-05 9.8812753e-01]
# Maximun Probability =  0.9881275
# Difference of prob  0.9762550592422485
# Results =  [8.5750682e-04 1.0835957e-02 3.7982281e-05 9.8826873e-01]
# Maximun Probability =  0.98826873
# Difference of prob  0.9765374660491943
# Results =  [8.6028635e-04 1.0722247e-02 3.8422477e-05 9.8837918e-01]
# Maximun Probability =  0.9883792
# Difference of prob  0.9767583608627319
# Results =  [8.6610112e-04 1.0631397e-02 3.8837086e-05 9.8846376e-01]
# Maximun Probability =  0.98846376
# Difference of prob  0.9769275188446045
# Results =  [8.7088608e-04 1.0496104e-02 3.8914772e-05 9.8859417e-01]
# Maximun Probability =  0.9885942
# Difference of prob  0.9771883487701416
# Results =  [8.9321018e-04 1.1413226e-02 3.9771290e-05 9.8765385e-01]
# Maximun Probability =  0.98765385
# Difference of prob  0.9753077030181885
# Maximun Probability =  0.7975146
# Difference of prob  0.5950292348861694
# Results =  [2.5586871e-02 1.8149464e-01 2.2351861e-04 7.9269516e-01]
# Maximun Probability =  0.79269516
# Difference of prob  0.5853903293609619
# Results =  [2.6593264e-02 1.8535708e-01 2.2808160e-04 7.8782177e-01]
# Maximun Probability =  0.78782177
# Difference of prob  0.5756435394287109
# Results =  [2.7463002e-02 1.8936817e-01 2.3176272e-04 7.8293729e-01]
# Maximun Probability =  0.7829373
# Difference of prob  0.5658745765686035
# Results =  [2.8245749e-02 1.9330449e-01 2.3493600e-04 7.7821505e-01]
# Maximun Probability =  0.77821505
# Difference of prob  0.5564301013946533
# Results =  [2.9007280e-02 1.9707040e-01 2.3833921e-04 7.7368420e-01]
# Maximun Probability =  0.7736842
# Difference of prob  0.5473684072494507
# Results =  [2.9637331e-02 2.0089945e-01 2.4174440e-04 7.6922166e-01]
# Maximun Probability =  0.76922166
# Difference of prob  0.5384433269500732
# Results =  [3.0188695e-02 2.0498207e-01 2.4530798e-04 7.6458412e-01]
# Maximun Probability =  0.7645841
# Difference of prob  0.5291682481765747
# Results =  [3.0762309e-02 2.0878512e-01 2.4892343e-04 7.6020384e-01]
# Maximun Probability =  0.76020384
# Difference of prob  0.5204076766967773
# Results =  [3.1303819e-02 2.1273373e-01 2.5224066e-04 7.5571042e-01]
# Maximun Probability =  0.7557104
# Difference of prob  0.5114208459854126
# Results =  [3.1977035e-02 2.1621852e-01 2.5580902e-04 7.5154883e-01]
# Maximun Probability =  0.7515488
# Difference of prob  0.503097653388977
# Results =  [3.2585129e-02 2.1986488e-01 2.5937165e-04 7.4729079e-01]
# Maximun Probability =  0.7472908
# Difference of prob  0.49458158016204834
# Results =  [3.3474185e-02 2.2476162e-01 2.6524960e-04 7.4149907e-01]
# Maximun Probability =  0.74149907
# Difference of prob  0.4829981327056885
# Results =  [3.4326144e-02 2.2946939e-01 2.7032619e-04 7.3593426e-01]
# Maximun Probability =  0.73593426
# Difference of prob  0.47186851501464844
# Results =  [3.5152875e-02 2.3481956e-01 2.7563266e-04 7.2975206e-01]
# Maximun Probability =  0.72975206
# Difference of prob  0.4595041275024414
# Results =  [3.5919379e-02 2.4028973e-01 2.8097749e-04 7.2351015e-01]
# Maximun Probability =  0.72351015
# Difference of prob  0.4470202922821045
# Results =  [3.6657024e-02 2.4603975e-01 2.8595250e-04 7.1701735e-01]
# Maximun Probability =  0.71701735
# Difference of prob  0.43403470516204834
# Results =  [3.7416369e-02 2.5151208e-01 2.9060096e-04 7.1078110e-01]
# Maximun Probability =  0.7107811
# Difference of prob  0.42156219482421875
# Results =  [3.8111974e-02 2.5718862e-01 2.9505955e-04 7.0440453e-01]
# Maximun Probability =  0.70440453
# Difference of prob  0.4088090658187866
# Results =  [3.8780764e-02 2.6279032e-01 2.9966104e-04 6.9812936e-01]
# Maximun Probability =  0.69812936
# Difference of prob  0.39625871181488037
# Results =  [3.9263442e-02 2.6321250e-01 3.4021647e-04 6.9718391e-01]
# Maximun Probability =  0.6971839
# Difference of prob  0.3943678140640259
# Results =  [3.9824955e-02 2.6369035e-01 3.8872290e-04 6.9609612e-01]
# Maximun Probability =  0.6960961
# Difference of prob  0.3921922445297241
# Results =  [4.0350243e-02 2.6411331e-01 4.3551734e-04 6.9510102e-01]
# Maximun Probability =  0.695101
# Difference of prob  0.39020204544067383
# Results =  [4.0851887e-02 2.6447198e-01 4.8617530e-04 6.9419003e-01]
# Maximun Probability =  0.69419
# Difference of prob  0.3883800506591797
# Results =  [4.1359238e-02 2.6510394e-01 5.5432570e-04 6.9298261e-01]
# Maximun Probability =  0.6929826
# Difference of prob  0.3859652280807495
# Results =  [4.1912988e-02 2.6600119e-01 6.2514393e-04 6.9146073e-01]
# Maximun Probability =  0.6914607
# Difference of prob  0.3829214572906494
# Results =  [4.2431090e-02 2.6691043e-01 6.8228005e-04 6.8997622e-01]
# Maximun Probability =  0.6899762
# Difference of prob  0.37995243072509766
# Results =  [0.04300736 0.26765883 0.00073433 0.6885996 ]
# Maximun Probability =  0.6885996
# Difference of prob  0.3771991729736328
# Results =  [0.04365732 0.26833013 0.00078897 0.6872236 ]
# Maximun Probability =  0.6872236
# Difference of prob  0.374447226524353
# Results =  [0.04449764 0.26919633 0.00084865 0.6854574 ]
# Maximun Probability =  0.6854574
# Difference of prob  0.3709148168563843
# Results =  [0.04502483 0.2695298  0.00087607 0.6845693 ]
# Maximun Probability =  0.6845693
# Difference of prob  0.36913859844207764
# Results =  [0.04608308 0.27004886 0.00091064 0.68295753]
# Maximun Probability =  0.68295753
# Difference of prob  0.36591506004333496
# Results =  [0.04730458 0.27040976 0.00094365 0.6813421 ]
# Maximun Probability =  0.6813421
# Difference of prob  0.3626842498779297
# Results =  [0.04836786 0.27117482 0.00099191 0.6794656 ]
# Maximun Probability =  0.6794656
# Difference of prob  0.35893118381500244
# Results =  [0.04944633 0.27194786 0.00104206 0.6775639 ]
# Maximun Probability =  0.6775639
# Difference of prob  0.35512781143188477
# Results =  [0.05007906 0.27220097 0.0010677  0.6766525 ]
# Maximun Probability =  0.6766525
# Difference of prob  0.35330498218536377
# Results =  [0.05142226 0.27258825 0.00110752 0.6748821 ]
# Maximun Probability =  0.6748821
# Difference of prob  0.34976422786712646
# Results =  [0.05244524 0.27286625 0.00114238 0.6735463 ]
# Maximun Probability =  0.6735463
# Difference of prob  0.3470926284790039
# Results =  [0.05404091 0.27325305 0.00119355 0.6715126 ]
# Maximun Probability =  0.6715126
# Difference of prob  0.34302520751953125
# [INFO] cleaning up...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-290459aa6d14> in <module>
#     138 print("[INFO] cleaning up...")
#     139 writer.release()
# --> 140 vs.stream.release()
#
# AttributeError: 'cv2.VideoCapture' object has no attribute 'stream'
